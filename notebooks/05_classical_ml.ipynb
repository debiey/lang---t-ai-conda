# %% [markdown]
# # 05 — Classical Machine Learning
#
# Build your first real machine learning models with scikit-learn (classification & regression).
#
# ---
#
# **This notebook is part of the Lang & T AI Summer Lab.**
#
# Work through the cells carefully. Do all exercises marked **Your Turn**.

# %% [markdown]
# ## Getting Started
#
# Run the cell below to make sure your environment is working.

# %%
print("Environment is ready! Let's learn.")

# %% [markdown]
# ## Content coming soon in full version
#
# This is a placeholder structure. The full teaching content will be added progressively.
#
# **Next:** `06_intro_neural_networks.ipynb`
